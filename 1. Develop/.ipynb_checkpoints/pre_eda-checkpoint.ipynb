# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import lightgbm as lgbm
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
data = pd.read_csv('data.csv', sep = '\t')
print(data.shape)
# Out:
# (73489, 105)

# %%
data.head()
# Out:
#    Q1A   Q1I      Q1E  Q2A   Q2I      Q2E  Q3A   Q3I      Q3E  Q4A  ...  \
# 0  3.0   6.0  21017.0  3.0   7.0  18600.0  5.0  20.0  14957.0  2.0  ...
# 1  5.0  17.0   3818.0  5.0   9.0   7850.0  1.0  16.0   5902.0  3.0  ...
# 2  5.0  16.0   4186.0  5.0  12.0   2900.0  1.0   2.0   7160.0  1.0  ...
# 3  2.0  12.0   9373.0  4.0   1.0  10171.0  2.0   7.0  10117.0  1.0  ...
# 4  5.0  13.0   9465.0  5.0   7.0   5284.0  2.0  19.0   8872.0  1.0  ...
#
#    screenw  screenh  hand  religion  orientation  race  voted  married  \
# 0   1440.0    900.0     1         7            1    30      1        2
# 1   1536.0    864.0     1         1            1    60      2        1
# 2    375.0    667.0     1         2            2    10      2        1
# 3   1280.0    720.0     1         6            1    60      1        3
# 4    360.0    640.0     1         4            3    60      1        1
#
#    familysize                    major
# 0           5               Marketing
# 1           2              mathematics
# 2           2                Chemistry
# 3           2  international relations
# 4           2               Management
#
# [5 rows x 105 columns]

# %%
# Q_A : 유저의 답
# Q_I : 아이템의 위치
# Q_E : 문항 응답 시간

# %%
# country 변수에서 US만 사용
data_pre = data[data['country']=='US']
data_pre = data_pre.drop('country', axis = 1)

# vote에서 0[이상치]을 제거
# 1 = yes, 2 = no
data_pre = data_pre[data_pre['voted']!=0]

# major 변수 제거
data_pre = data_pre.drop('major', axis = 1)

# %%
data_pre.shape
# Out:
# (33705, 103)

# %%
models_list = [x for x in data.columns if not x.endswith("I")]
models_list
# Out:
# ['Q1A',
#  'Q1E',
#  'Q2A',
#  'Q2E',
#  'Q3A',
#  'Q3E',
#  'Q4A',
#  'Q4E',
#  'Q5A',
#  'Q5E',
#  'Q6A',
#  'Q6E',
#  'Q7A',
#  'Q7E',
#  'Q8A',
#  'Q8E',
#  'Q9A',
#  'Q9E',
#  'Q10A',
#  'Q10E',
#  'Q11A',
#  'Q11E',
#  'Q12A',
#  'Q12E',
#  'Q13A',
#  'Q13E',
#  'Q14A',
#  'Q14E',
#  'Q15A',
#  'Q15E',
#  'Q16A',
#  'Q16E',
#  'Q17A',
#  'Q17E',
#  'Q18A',
#  'Q18E',
#  'Q19A',
#  'Q19E',
#  'Q20A',
#  'Q20E',
#  'country',
#  'introelapse',
#  'testelapse',
#  'surveyelapse',
#  'TIPI1',
#  'TIPI2',
#  'TIPI3',
#  'TIPI4',
#  'TIPI5',
#  'TIPI6',
#  'TIPI7',
#  'TIPI8',
#  'TIPI9',
#  'TIPI10',
#  'VCL1',
#  'VCL2',
#  'VCL3',
#  'VCL4',
#  'VCL5',
#  'VCL6',
#  'VCL7',
#  'VCL8',
#  'VCL9',
#  'VCL10',
#  'VCL11',
#  'VCL12',
#  'VCL13',
#  'VCL14',
#  'VCL15',
#  'VCL16',
#  'education',
#  'urban',
#  'gender',
#  'engnat',
#  'age',
#  'screenw',
#  'screenh',
#  'hand',
#  'religion',
#  'orientation',
#  'race',
#  'voted',
#  'married',
#  'familysize',
#  'major']

# %%
data['country'].value_counts()
# Out:
# US    33959
# GB     5487
# CA     4761
# AU     2734
# IN     1621
#       ...
# GP        1
# ML        1
# MQ        1
# CI        1
# TD        1
# Name: country, Length: 187, dtype: int64

# %%
# voting이 반응변수로 괜찮은지 실험
train, test = train_test_split(data_pre, test_size = 0.2, random_state=8)

# %%
train_x = train.drop('voted', axis = 1)
train_y = train['voted']
test_x = test.drop('voted', axis = 1)
test_y = test['voted']

# %%
train_x
# Out:
#        Q1A   Q1I      Q1E  Q2A   Q2I      Q2E  Q3A   Q3I      Q3E  Q4A  ...  \
# 13689  1.0  12.0  10001.0  1.0   7.0   5853.0  4.0   6.0  16224.0  4.0  ...
# 36109  1.0   9.0   7883.0  3.0  12.0   8421.0  4.0   5.0   9066.0  5.0  ...
# 20715  3.0  18.0   2829.0  1.0  13.0   4527.0  4.0   4.0   5696.0  2.0  ...
# 23154  2.0   5.0   5967.0  4.0  18.0   6928.0  5.0   6.0   4852.0  4.0  ...
# 25202  1.0  15.0   3576.0  2.0  12.0  11189.0  2.0  14.0   9826.0  1.0  ...
# ...    ...   ...      ...  ...   ...      ...  ...   ...      ...  ...  ...
# 11700  1.0   9.0  10217.0  2.0  13.0   5649.0  1.0  10.0   9587.0  4.0  ...
# 19778  3.0  16.0   8700.0  5.0   6.0   3902.0  3.0   8.0  46254.0  2.0  ...
# 37103  5.0  14.0  12457.0  4.0  16.0   9237.0  5.0   2.0  15495.0  2.0  ...
# 54398  4.0  15.0   5807.0  4.0  13.0   4010.0  2.0   4.0   5040.0  3.0  ...
# 9843   4.0  19.0   4037.0  4.0  18.0   4147.0  1.0  20.0   4949.0  4.0  ...
#
#        engnat  age  screenw  screenh  hand  religion  orientation  race  \
# 13689       1   34   1920.0   1080.0     1         5            1    60
# 36109       1   44   1024.0    768.0     1         6            1    60
# 20715       1   24   1366.0    768.0     3         2            2    60
# 23154       1   32   1280.0    800.0     1         1            1    70
# 25202       1   15   1366.0    768.0     1         9            1    60
# ...       ...  ...      ...      ...   ...       ...          ...   ...
# 11700       1   57   1366.0    768.0     2         1            4    60
# 19778       1   41    320.0    568.0     1         4            1    60
# 37103       1   39    414.0    736.0     1         1            1    60
# 54398       1   18    375.0    667.0     3        12            2    60
# 9843        1   31    320.0    568.0     1         4            1    60
#
#        married  familysize
# 13689        2           2
# 36109        2           2
# 20715        1           2
# 23154        2           1
# 25202        1           2
# ...        ...         ...
# 11700        1           1
# 19778        2           4
# 37103        2           2
# 54398        1           2
# 9843         2           3
#
# [26964 rows x 102 columns]

# %%
# lgbm으로 분석
model = lgbm.LGBMClassifier(n_estimators=500)
model.fit(train_x, train_y)
# Out:
# LGBMClassifier(n_estimators=500)

# %%
pred_y = model.predict(test_x)

# %%
confusion_matrix(test_y, pred_y)
# Out:
# array([[2510,  620],
#        [1226, 2385]], dtype=int64)

# %%
accuracy_score(test_y, pred_y)
# Out:
# 0.7261533897047916
